# %% [markdown]
# ###### Q: create a DataFrame by passing a list of dictionaries and the row indices.

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data, index=['first', 'second'])
df
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %% [markdown]
# ###### Q:Display a summary of the basic information about  data ('medium_data.csv')

# %%
medium_data=pd.read_csv('medium_data.csv')
medium_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508 entries, 0 to 6507
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6508 non-null   int64
#  1   url           6508 non-null   object
#  2   title         6508 non-null   object
#  3   subtitle      3479 non-null   object
#  4   image         6361 non-null   object
#  5   claps         6508 non-null   int64
#  6   responses     6508 non-null   object
#  7   reading_time  6508 non-null   int64
#  8   publication   6508 non-null   object
#  9   date          6508 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 508.6+ KB

# %% [markdown]
# **Q:** Select just the 'subtitle' and 'date' columns from the DataFrame `df`.

# %%
medium_data.loc[:,['subtitle','date']]
#medium_data.iloc[:,[3,9]]
# combine medium_data['subtitle'] and medium_data['date']
# Out:
#                                                subtitle        date
# 0                                                   NaN  2019-05-30
# 1                                                   NaN  2019-05-30
# 2                      A Grammar of Graphics for Python  2019-05-30
# 3               When I work on Python projects dealing…  2019-05-30
# 4                       One example of building neural…  2019-05-30
# ...                                                 ...         ...
# 6503              Basic copywriting choices with a big…  2019-12-05
# 6504  Lessons from who might be the most popular bra...  2019-12-05
# 6505  How to acquire customers without wasting money...  2019-12-05
# 6506                           Save time and effort by…  2019-12-05
# 6507                    An A-to-Z guide for non-writers  2019-12-05
#
# [6508 rows x 2 columns]

# %% [markdown]
# **Q:** in data ('medium_data.csv')
# - count of only the articles where the number of claps is greater than 1000.
# - Select only the articles that it is publicated by Towards Data Science where the number of claps is greater than 1000.

# %%
sum(medium_data.claps > 1000)
#medium_data.query('claps > 1000').count()
#medium_data.loc[medium_data.claps > 1000].count()
#medium_data.loc[medium_data.claps > 1000].shape
# Out:
# 326

# %%
medium_data.query("(claps > 1000) & (publication == 'Towards Data Science')")
#medium_data.loc[(medium_data.claps > 1000) & (medium_data.publication == 'Towards Data Science')]
# Out:
#         id                                                url  \
# 1        2  https://towardsdatascience.com/hands-on-graph-...
# 193    194  https://towardsdatascience.com/use-cython-to-g...
# 195    196  https://towardsdatascience.com/predicting-vs-e...
# 361    362  https://towardsdatascience.com/the-problem-wit...
# 584    585  https://towardsdatascience.com/six-recommendat...
# ...    ...                                                ...
# 5853  5854  https://towardsdatascience.com/a-complete-expl...
# 5857  5858  https://towardsdatascience.com/predicting-stoc...
# 5963  5964  https://towardsdatascience.com/plotting-with-p...
# 6166  6167  https://towardsdatascience.com/three-great-add...
# 6332  6333  https://towardsdatascience.com/the-most-in-dem...
#
#                                                   title  \
# 1     Hands-on Graph Neural Networks with PyTorch & ...
# 193   Use Cython to get more than 30X speedup on you...
# ...

# %% [markdown]
# **Q:** change value of column `id`  into numbers that has mean = 0.0 in data ('medium_data.csv').

# %%
import numpy as np
medium_data['id']=np.random.randn(len(medium_data))
medium_data
# Out:
#             id                                                url  \
# 0    -0.734141  https://towardsdatascience.com/a-beginners-gui...
# 1    -0.058548  https://towardsdatascience.com/hands-on-graph-...
# 2    -0.216687  https://towardsdatascience.com/how-to-use-ggpl...
# 3     2.148414  https://towardsdatascience.com/databricks-how-...
# 4     1.111496  https://towardsdatascience.com/a-step-by-step-...
# ...        ...                                                ...
# 6503  0.852399  https://medium.com/better-marketing/we-vs-i-ho...
# 6504 -1.314052  https://medium.com/better-marketing/how-donald...
# 6505  1.713488  https://medium.com/better-marketing/content-an...
# 6506  1.369942  https://medium.com/better-marketing/5-question...
# 6507 -1.110264  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# 0     A Beginner’s Guide to Word Embedding with Gens...
# 1     Hands-on Graph Neural Networks with PyTorch & ...
# ...

# %% [markdown]
# ###### Q: Get the least reading time in each title articles category in data ('medium_data.csv').

# %%
medium_data.groupby('title').reading_time.min()
# Out:
# title
# #CopyPasteCris and the fight to stop writing from devolving into content marketing                8
# #Fail: Artificial Intelligence is a Science                                                      13
# #NoProcesses — Introduction                                                                       7
# (Book Review) The Big Nine: How The Tech Titans & Their Thinking Machines Could Warp Humanity     5
# (Mostly Undiscussed) Advice for Beginning Authors                                                 5
#                                                                                                  ..
# “Old Town Road” Teaches Us We Can Do Anything                                                     4
# “We” vs “I” — How Should You Talk About Yourself on Your Website?                                 6
# …did You Die?                                                                                     3
# ...

# %% [markdown]
# **Q:** Replace Missing Data in `subtitle` by text='no subtitle'  in data ('medium_data.csv').

# %%
medium_data.loc[:,'subtitle'].fillna("no subtitle")
# Out:
# 0                                             no subtitle
# 1                                             no subtitle
# 2                        A Grammar of Graphics for Python
# 3                 When I work on Python projects dealing…
# 4                         One example of building neural…
#                               ...
# 6503                Basic copywriting choices with a big…
# 6504    Lessons from who might be the most popular bra...
# 6505    How to acquire customers without wasting money...
# 6506                             Save time and effort by…
# 6507                      An A-to-Z guide for non-writers
# Name: subtitle, Length: 6508, dtype: object
